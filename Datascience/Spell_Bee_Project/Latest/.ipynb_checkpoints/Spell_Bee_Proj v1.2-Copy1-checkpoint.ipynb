# %%
# Importing Libraries
from PyPDF2 import PdfFileReader
import numpy as np
import tabula
import pandas as pd

# %% [markdown]
# PikePDF can be used to open encrypted files (Created by Acrobat 6.0). Below is the simple code:
# Output file is no longer password protected.

# %%
from pikepdf import Pdf
with Pdf.open('Bee_Word_2020.pdf') as pdf:
    pdf.save('Bee_Word_2020_decrypt.pdf')

# %% [markdown]
# # 2021 Word of Champions

# %%
class Spell_Bee:
    def __init__(self,path):
        # Initialization
        self.words_array=[]
        self.level = 'ONE'
        self.dataset = self.Create_DataFrame()
        self.path = path
    
    def Create_DataFrame(self):
        return pd.DataFrame({'Difficulty Level': self.level, 'Words':self.words_array})

    
    
    #Opening File
    def Open_Pdf(self):
        f = open(self.path,'rb') 
        pdf = PdfFileReader(f)
        tot_pg= pdf.getNumPages()
        #print('After getnum pages')
        f.close()
        #print('total page: ', tot_pg)       
        return tot_pg
    
    def Append_rows(self,pg):
        def Array_handling(df_data):
            sample_list=''
            for item in df_data:
                sample_list= ','.join(item)
            x=np.array(sample_list.split(','))
            y=np.array(df_data[0])
            return np.append(x,y)
        data=tabula.read_pdf(self.path,pages=pg)
        self.words_array=np.append(self.words_array,Array_handling(data))
    
    def Page_Extract(self,page):
        def Lvl_chk(x):
            num_lst =['ONE','TWO', 'THREE']
            column_val=''

            for i in num_lst:

                if i in x:

                    column_val = i
                    return column_val
            return None
        
    
    
        for pg in range(page+1):
            print('Page no:',pg)
            df_new=tabula.read_pdf(filename, pages=pg,area=(30,331,70,420))
            x=str(df_new)


            column_val =Lvl_chk(x)

            if column_val and self.level == column_val:
                self.Append_rows(pg)
                
            elif column_val :
  
                df2 = self.Create_DataFrame()
                self.dataset =pd.concat([self.dataset,df2], ignore_index=True, axis=0)

                self.level = column_val
                self.words_array=[]
                self.Append_rows(pg)
        
        df2 = self.Create_DataFrame()
        self.dataset =pd.concat([self.dataset,df2], ignore_index=True, axis=0)
        
            
filename=input('\nInput Filename(PDF):') 
Output_csv = input('\nOutput Filename(CSV ):')
Sb = Spell_Bee(filename)
page = Sb.Open_Pdf()
Sb.Page_Extract(page)
Output=Sb.dataset
dataframe_out = Output.copy()
# handling null values
Output.dropna(axis=0,how='any',inplace=True)
import re
def Orsplit(x):
    match = re.findall('OR\s*\**([\w+\s*\w*]*)|\**(\w+((\s*|-)\w+)*)|\**([\w+\s*\w*]*)',x)
    for item in match[0]:
        if item != '':
            return item 
        
Output['Words'] = Output['Words'].apply(Orsplit)

Output.to_csv(Output_csv,encoding='utf-8-sig') # writing into csv format file
#print('Output:', Output)
# Out:
# Input Filename(PDF):Bee_Docs/Bee_Word_2020_decrypt.pdf
#
# Output Filename(CSV ):Bee_Docs/2020_Words of the Champions_Output.csv
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# Page no: 0
# Page no: 1
# Page no: 2
# Page no: 3
# Page no: 4
# Page no: 5
# Page no: 6
# Page no: 7
# Page no: 8
# Page no: 9
# Page no: 10
# Page no: 11
# Page no: 12
# Page no: 13
# Page no: 14
# Page no: 15
# Page no: 16
# Page no: 17
# Page no: 18
# Page no: 19
# Page no: 20
# Page no: 21
# Page no: 22
# Page no: 23
# Page no: 24
# Page no: 25
# Page no: 26
# Page no: 27
# Page no: 28

# %%
Output.to_csv('Bee_Docs/2020_Words Of Champions_Output.csv',encoding='utf-8-sig')

# %%
Output
# Out:
#      Difficulty Level        Words
# 0                 ONE      punting
# 1                 ONE         seal
# 2                 ONE          ash
# 3                 ONE      filters
# 4                 ONE      beeswax
# ...               ...          ...
# 4080            THREE   epideictic
# 4081            THREE        zazen
# 4082            THREE        Foley
# 4083            THREE    wasteweir
# 4084            THREE  encarnadine
#
# [4058 rows x 2 columns]

# %% [markdown]
# # 2020 School of Words - Uploading directly to Excel

# %%
import numpy as np
import tabula
import pandas as pd
data = tabula.read_pdf("Bee_Docs/Bee_School Of Words_2020_decrypt.pdf", pages='all', multiple_tables=True)
Bee_Soc_2020 = pd.DataFrame()
for i in data:    #x values in list []
    #print("printing all the table from the sheet", i)
    df_table = pd.DataFrame(i)
    Bee_Soc_2020 = Bee_Soc_2020.append(df_table)
Bee_Soc_2020.to_excel('Bee_Docs/2020_School of Words_Output.xlsx', header=True, index = True)

# %%
data
# Out:
# [     26.   grown-ups  (plural noun)  \
#  0    NaN         NaN            NaN
#  1   27.0      pieces  (plural noun)
#  2   28.0       brass         (noun)
#  3    NaN         NaN            NaN
#  4   29.0     onshore       (adverb)
#  5   30.0      stunts  (plural noun)
#  6   31.0        deny         (verb)
#  7   32.0       jolly    (adjective)
#  8   33.0      powder         (noun)
#  9   34.0  earthquake         (noun)
#  10   NaN         NaN            NaN
#  11  35.0      walnut         (noun)
#  12  36.0     sawdust         (noun)
#  13   NaN         NaN            NaN
#  14  37.0   flustered         (verb)
#  15  38.0      barber         (noun)
#  16   NaN         NaN            NaN
#  17  39.0      chimes         (verb)
#  18  40.0       cabin         (noun)
#  19  41.0       faint    (adjective)
#  20   NaN         NaN            NaN
#  21  42.0      manger         (noun)
#  22  43.0  peppermint         (noun)
#  23   NaN         NaN            NaN
#  24  44.0       broth         (noun)
#  25  45.0         ash         (noun)
#  26   NaN         NaN            NaN
#  27  46.0       flame         (noun)
#  28  47.0       grits  (plural noun)
#  29   NaN         NaN            NaN
#  30  48.0       cliff         (noun)
#  31  49.0         hem         (noun)
#
#     adults : those that have reached full physical and intellectual
#  0                                        development.
#  1                             parts of a whole thing.
#  2   a typically yellow alloy made of copper with z...
#  3   being formed and is harder and stronger than c...
#  4                                 within the country.
#  5   feats or tricks which display significant stre...
#  6   to turn down or give a negative answer to a pe...
#  7                                             joyous.
#  8         a substance made up of very fine particles.
#  9   a trembling or shaking of the earth that accom...
#  10                                         movements.
#  11  an edible nut that comes from a tree of the sa...
#  12  dry pulverized particles of wood or stone made...
#  13  cutting material with a manually operated or p...
#  14                                 confused, muddled.
#  15  one whose job is to cut and dress hair, as wel...
#  16                                            beards.
#  17  makes a musical and harmonious sound, like a b...
#  18  a small single-story low-roofed house of simpl...
#  19  feeble, dizzy and likely to pass out due to hu...
#  20                                        or emotion.
#  21  an open box in which food is placed for horses...
#  22  a sharp and strong smelling plant with dark gr...
#  23                   of small pink flowers in spikes.
#  24  liquid which was used to cook meat, fish, grai...
#  25  the material that is left behind after combust...
#  26                            coal) have been burned.
#  27                    the part of a fire which glows.
#  28  grains such as maize, wheat or barley which ha...
#  29                                   coarsely ground.
#  30    a very steep face of rock or earth : precipice.
#  31  an edge of cloth (such as for a skirt, sleeve ...               ,
#      124.      beam  (noun)  \
#  0    NaN       NaN     NaN
#  1  125.0      crew  (noun)
#  2  126.0     crate  (noun)
#  3  127.0     hotel  (noun)
#  4  128.0     stray  (noun)
#  5    NaN       NaN     NaN
#  6  129.0    gallop  (noun)
#  7  130.0  dinosaur  (noun)
#
#    a long piece of heavy wood that is suitable to use in house
#  0                                      construction.
#  1            the group of people who work on a ship.
#  2       a container that is used to transport items.
#  3  a building with many rooms that are used for o...
#  4  a domestic animal that has left its enclosure ...
#  5                                  large or is lost.
#  6            the natural three-beat gait of a horse.
#  7           a member of a group of extinct reptiles.           ,
#       143.       yoga  (noun)  \
#  0     NaN        NaN     NaN
#  1   144.0     burlap  (noun)
#  2     NaN        NaN     NaN
#  3   145.0     blazer  (noun)
#  4     NaN        NaN     NaN
#  5   146.0   trombone  (noun)
#  6     NaN        NaN     NaN
#  7   147.0  trembling  (verb)
#  8   148.0     calmed  (verb)
#  9     NaN        NaN     NaN
#  10  149.0     police  (noun)
#
#     a group of exercises for achieving well-being and control of mind and
#  0                                               body.
#  1   a course heavy plain-woven fabric typically ma...
#  2        that is used for bagging and wrapping items.
#  3   a single-breasted sports jacket usually with b...
#  4   color that has a notched collar and patch pock...
#  5   a brass instrument that consists of a long cyl...
#  6   ends in a bell and has a movable slide which m...
#  7             quaking due to fear or another emotion.
#  8   made peaceful : induced quiet and peace in pla...
#  9                                            passion.
#  10  the department of the government which is conc...                     ,
#       156.         teak         (noun)  \
#  0     NaN          NaN            NaN
#  1     NaN          NaN            NaN
#  2   157.0      transit         (noun)
#  3     NaN          NaN            NaN
#  4   158.0    cannonade         (noun)
#  5   159.0     appetite         (noun)
#  6   160.0      luggage         (noun)
#  7     NaN          NaN            NaN
#  8   161.0     ramparts  (plural noun)
#  9   162.0        vinyl         (noun)
#  10    NaN          NaN            NaN
#  11    NaN          NaN            NaN
#  12  163.0  anemometers  (plural noun)
#  13  164.0       dainty    (adjective)
#  14  165.0       buckle         (verb)
#  15    NaN          NaN            NaN
#  16  166.0      vividly       (adverb)
#  17  167.0        briny    (adjective)
#  18  168.0     pavement         (noun)
#  19  169.0       garnet         (noun)
#  20    NaN          NaN            NaN
#  21  170.0       furrow         (verb)
#  22  171.0       sprawl         (verb)
#  23  172.0       museum         (noun)
#  24    NaN          NaN            NaN
#  25  173.0         wren         (noun)
#  26  174.0       legend         (noun)
#  27    NaN          NaN            NaN
#  28  175.0   transistor         (noun)
#  29    NaN          NaN            NaN
#  30    NaN          NaN            NaN
#  31  176.0      amplify         (verb)
#  32    NaN          NaN            NaN
#  33  177.0     security         (noun)
#  34  178.0      refrain         (noun)
#  35  179.0      tactics  (plural noun)
#  36  180.0     shepherd         (noun)
#
#     the hard, strong, durable, yellowish brown wood of a tall East Indian
#  0   timber tree which is highly resistant to insec...
#  1                              used for shipbuilding.
#  2   the public transportation of people by bus, su...
#  3                               system of conveyance.
#  4        a noisy persistent attack (as of questions).
#  5           the desire to eat when food is available.
#  6   suitcases, bags used for travel or other artic...
#  7                              traveler's belongings.
#  8                                protective barriers.
#  9   any of a group of tough durable plastics based...
#  10  especially in the forming of films and sheetin...
#  11                                           records.
#  12         tools used to gauge the speed of the wind.
#  13  characterized by beauty that is delicate in na...
#  14  to secure two loose ends of something (such as...
#  15          having a fastening and the other a catch.
#  16                        intensely, sharply, keenly.
#  17                                             salty.
#  18  the surface of a public thoroughfare which is ...
#  19  a brittle material which is typically red in c...
#  20                                          crystals.
#  21            to cultivate or till as if with a plow.
#  22  to lie or sit with arms and legs stretched out...
#  23  a building or institution which is devoted to ...
#  24  and display of objects of lasting interest and...
#  25          any of various small brown singing birds.
#  26  someone having a special status as a result of...
#  27  qualities that are typically partly real and p...
#  28  an electronic device made of a small block of ...
#  29  three electrodes on it and that conducts elect...
#  30               direction to the opposite direction.
#  31  to expand, extend or enlarge a statement or id...
#  32                                      illustration.
#  33                freedom from care, anxiety or fear.
#  34  a phrase or verse that recurs regularly typica...
#  35                    methods : systems of procedure.
#  36  a man employed in tending, feeding and guardin...                     ,
#       194.          pulse  (noun)  \
#  0     NaN            NaN     NaN
#  1     NaN            NaN     NaN
#  2   195.0        cottage  (noun)
#  3   196.0        garland  (noun)
#  4     NaN            NaN     NaN
#  5   197.0           gnaw  (verb)
#  6   198.0        comfort  (noun)
#  7   199.0       caroling  (verb)
#  8     NaN   OR carolling     NaN
#  9   200.0    foolishness  (noun)
#  10  201.0  constellation  (noun)
#  11  202.0      sundering  (verb)
#  12  203.0       juncture  (noun)
#  13  204.0       exploits  (verb)
#  14  205.0  rabble-rouser  (noun)
#
#     a regular wave of distension in the arteries that is a result of blood
#  0   progressing through an artery at each contract...
#  1                                          the heart.
#  2         a small house typically used in the summer.
#  3   a wreath of leaves or flowers that is worn on ...
#  4                                         decoration.
#  5                  to bite or chew on with the teeth.
#  6         enjoyment in physical or mental well-being.
#  7   traveling outside in a group to sing Christmas...
#  8                                                 NaN
#  9           the state of lacking seriousness : folly.
#  10             any of the 88 configurations of stars.
#  11                         breaking or forcing apart.
#  12                                   a seam or joint.
#  13                          takes undue advantage of.
#  14  a person who stirs up the masses of the people...                      ,
#       295.      gabled    (adjective)  \
#  0   296.0      settle         (verb)
#  1   297.0      somber    (adjective)
#  2     NaN   OR sombre            NaN
#  3   298.0    tampered         (verb)
#  4   299.0       loyal    (adjective)
#  5   300.0  remarkable    (adjective)
#  6   301.0      joists  (plural noun)
#  7     NaN         NaN            NaN
#  8   302.0  scrambling         (verb)
#  9   303.0   inspector         (noun)
#  10  304.0  distressed    (adjective)
#  11  305.0      smudge         (noun)
#  12  306.0    throttle         (verb)
#  13  307.0  perfection         (noun)
#  14  308.0     capable    (adjective)
#  15    NaN         NaN            NaN
#  16  309.0     gadgets  (plural noun)
#  17    NaN         NaN            NaN
#  18  310.0     channel         (noun)
#  19    NaN         NaN            NaN
#  20  311.0      chisel         (noun)
#  21    NaN         NaN            NaN
#  22  312.0     chimney         (noun)
#  23    NaN         NaN            NaN
#  24  313.0      minnow         (noun)
#  25    NaN         NaN            NaN
#  26  314.0      domain         (noun)
#
#     furnished with the vertical triangular portion of the end of a building.
#  0                             seat : to cause to sit.
#  1            dejected in appearance or mood : gloomy.
#  2                                                 NaN
#  3      interfered with so as to change for the worse.
#  4                     devoted to a person : faithful.
#  5                            worthy of being noticed.
#  6   the small timbers or iron or steel beams that ...
#  7   fashion stretching from wall to wall in a buil...
#  8                                moving with urgency.
#  9    a police officer ranking below a superintendent.
#  10                       overcome with pain or grief.
#  11                                a splotch or smear.
#  12  to choke : to stop the breathing of by any means.
#  13                flawlessness : freedom from defect.
#  14  marked by general efficiency and by adequate r...
#  15                                   and reliability.
#  16  typically small devices that are often conside...
#  17           found especially on pieces of machinery.
#  18  a band of frequencies able to accommodate a si...
#  19                                     communication.
#  20  a tool consisting of a metal bar with a sharpe...
#  21  for working on the surface of materials by chi...
#  22  a vertical structure incorporated into a build...
#  23                                    fumes or gases.
#  24  a very small fish that can grow up to three in...
#  25                                 common in streams.
#  26  a large subdivision of the Internet denoted by...                        ,
#      290. investigation  (noun)  \
#  0  291.0      accident  (noun)
#  1  292.0    discussion  (noun)
#  2  293.0      confused  (verb)
#  3  294.0     microwave  (verb)
#
#                                    study or research.
#  0                    an event that occurs by chance.
#  1  a consideration of a question typically occurr...
#  2  confounded : failed to distinguish between two...
#  3  to cook or heat food in an oven that prepares ...  ,
#       399.     tartaric  (adjective)  \
#  0     NaN          NaN          NaN
#  1   400.0        bindi       (noun)
#  2     NaN          NaN          NaN
#  3   401.0      Haitian  (adjective)
#  4   402.0        divan       (noun)
#  5     NaN          NaN          NaN
#  6   403.0    badminton       (noun)
#  7     NaN          NaN          NaN
#  8   404.0      bayonet       (noun)
#  9     NaN          NaN          NaN
#  10  405.0    currycomb       (noun)
#  11    NaN          NaN          NaN
#  12  406.0      haughty  (adjective)
#  13  407.0     hesitate       (verb)
#  14  408.0  opportunity       (noun)
#  15    NaN          NaN          NaN
#  16  409.0       Apollo       (noun)
#  17  410.0   accordance       (noun)
#  18  411.0  atmospheric  (adjective)
#
#     relating to or derived from a substance containing a white crystalline
#  0   salt and yeast or a type of acid obtained from...
#  1   a piece of jewelry or a mark (such as a red sp...
#  2                          especially by Hindu women.
#  3   relating to the people of Haiti or the island ...
#  4   a type of couch that usually doesn't have arms...
#  5                          meant to be used as a bed.
#  6   a game played on a court by two or four people...
#  7                    volley a shuttlecock over a net.
#  8   a steel blade made to be attached to the muzzl...
#  9   firearm that is fired while braced against the...
#  10  a grooming tool for horses that has rows of se...
#  11                                             teeth.
#  12                    arrogant or disdainfully proud.
#  13          to delay or pause typically for a moment.
#  14  a combination of time, place and circumstances...
#  15        suitable for a specific action or activity.
#  16                    a young man of graceful beauty.
#  17     agreement, such as of opinion, action or will.
#  18  relating to the entire mass of air that surrou...                      ,
#      430.    misdemeanor  (noun)  \
#  0    NaN             OR     NaN
#  1    NaN  *misdemeanour     NaN
#  2  431.0      asparagus  (noun)
#  3  432.0         solace  (verb)
#  4  433.0        argyria  (noun)
#
#    a crime that is not punishable by death or imprisonment in a state
#  0                                      penitentiary.
#  1                                                NaN
#  2  a plant that is widely grown for its edible an...
#  3                                        to console.
#  4  permanent dark skin discoloration caused by ab...                  ,
#      447.   hydrargyrum  (noun)  \
#  0  448.0     carborane  (noun)
#  1    NaN           NaN     NaN
#  2  449.0  denouncement  (noun)
#  3    NaN           NaN     NaN
#  4  450.0      Columbia  (noun)
#
#                                  the element mercury.
#  0  any of a class of compounds that are thermally...
#  1       in the synthesis of lubricants and polymers.
#  2  the act of making known or declaring someone s...
#  3                                 people in command.
#  4                                 the United States.  ]

# %%
import PyPDF2
PATH = 'Bee_Word_2020_decrypt.pdf'
with open(PATH, mode='rb') as f:        
    reader = PyPDF2.PdfFileReader(f)
   
    print(f"Number of page: {reader.getNumPages()}")
# Out:
# Number of page: 28

# %%
Output = dataframe_out.copy()
# handling null values
Output.dropna(axis=0,how='any',inplace=True)
#Output =['OR etouffee', 'bergère', '**kibitzer', 'force majeure', 'coup de grace', 'OR *löss','bric-a-brac']
import re
def Orsplit(x):
    match = re.findall('OR\s*\**([\w+\s*\w*]*)|\**(\w+((\s*|-)\w+)*)|\**([\w+\s*\w*]*)',x)
    #match=re.findall(r'OR\s*\**([\w+\s*\w*]*)|\**(\w+((\s*|-)\w+)*)|\**([\w+\s*\w*]*)',x)
    #print(match)
    for item in match[0]:
        #print(item, type(item))
        if item != '':
         return item
Output['Words'] = Output['Words'].apply(Orsplit)
#for item in Output:
 #   print('Final val:',Orsplit(item))
Output.to_csv('Bee_Docs/2021_Words of the Champions_Output.csv',encoding='utf-8-sig') # writing into csv format file

# %%
Output =['OR etouffee', 'bergère', '**kibitzer', 'force majeure', 'coup de grace', 'OR löss']
import re
def Orsplit(x):
    matched = re.match('OR\s*\**([\w+\s*\w*]*)|\**([\w+\s*\w*]*)',x)
    if matched:
        print(matched.groups())

#Output.to_csv(Output_csv) # writing into csv format file
for i in Output:
    Output_new = Orsplit(i)
# Out:
# ('etouffee', '', None)
# (None, None, 'bergère')
# (None, None, 'kibitzer')
# (None, None, 'force majeure')
# (None, None, 'coup de')
# ('löss', '', None)

# %%
#from io import BytesIO
Bee_data  = Output.copy()
#buffer = BytesIO()
#Bee_data = Bee_data.decode("utf8").encode("latin-1")
Bee_data.to_csv('Output_Bee_decrypt.csv',encoding='utf-8-sig')

# %%
import pyttsx3
engine = pyttsx3.init() # object creation
""" RATE"""
rate = engine.getProperty('rate')   # getting details of current speaking rate
print (rate)                        #printing current voice rate
engine.setProperty('rate', 125)     # setting up new voice rate
"""VOICE"""
voices = engine.getProperty('voices')       #getting details of current voice
#engine.setProperty('voice', voices[0].id)  #changing index, changes voices. o for male
engine.setProperty('voice', voices[1].id)   #changing index, changes voices. 1 for female
"""VOLUME"""
volume = engine.getProperty('volume')   #getting to know current volume level (min=0 and max=1
#printing current volume level
engine.setProperty('volume',1.0)    # setting up volume level  between 0 and 1
"""Speak words"""
engine.say("Hello World!")
engine.runAndWait()
engine.stop()
# Out:
# 200

# %%
def speak_word(df_level, Output):
    df=Output.copy()
    df=df.loc[df['Difficulty Level'] == df_level]
    print(df)
    #randomly select n number of rows out of the total existing row numbers from the dataframe df without replacement.
    n=1
    df_pick=df.take(np.random.permutation(len(df))[:n])
    print('Random Word ',df_pick.iloc[0][1])
    random_word = df_pick.iloc[0][1]
    engine.say(random_word)
    engine.runAndWait()
    engine.stop()
speak_word('ONE', Output)
# Out:
#     Difficulty Level      Words
# 0                ONE        gel
# 1                ONE        day
# 2                ONE     scorch
# 3                ONE       hear
# 4                ONE     sizzle
# ..               ...        ...
# 834              ONE     kernel
# 835              ONE    cornily
# 836              ONE      frock
# 837              ONE      gruel
# 838              ONE  teenagers
#
# [831 rows x 2 columns]
# Random Word  medallion

# %%
import speech_recognition as sr 
import pyttsx3  
  
# Initialize the recognizer  
r = sr.Recognizer()  
# Loop infinitely for user to 
# speak 
  
while(1):     
      
    # Exception handling to handle 
    # exceptions at the runtime 
    try: 
          
        # use the microphone as source for input. 
        with sr.Microphone() as source2: 
              
            # wait for a second to let the recognizer 
            # adjust the energy threshold based on 
            # the surrounding noise level  
            r.adjust_for_ambient_noise(source2, duration=0.2) 
              
            #listens for the user's input  
            audio2 = r.listen(source2) 
              
            # Using ggogle to recognize audio 
            MyText = r.recognize_google(audio2) 
            MyText = MyText.lower() 
  
            print("Did you say "+MyText) 
            SpeakText(MyText) 
              
    except sr.RequestError as e: 
        print("Could not request results; {0}".format(e)) 
          
    except sr.UnknownValueError: 
        print("unknown error occured")
def Listen_word(df_level, Output, MyText):
    df=Output.copy()
    df = df.loc[df['Difficulty Level'] == df_level]
    if MyText in df['Words']:
        return True
    else:
        return False
if Listen_word('ONE', Output, MyText):
    engine.say('You are Correct')
    engine.runAndWait()
    engine.stop()
else:
    engine.say('You are Wrong Try some other word')
    engine.runAndWait()
    engine.stop()

# %%
from random import sample

# given data frame df

# create random index
rindex =  np.array(sample(xrange(len(df)), 10))

# get 10 random rows from df
dfr = df.ix[rindex]
