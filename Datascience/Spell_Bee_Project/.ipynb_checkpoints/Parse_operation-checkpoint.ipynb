# %%
import tabula
import pandas as pd
import numpy as np
df_2019 =pd.read_csv('Bee_Output_2019.csv',encoding='utf-8') 
df_2019
# Out:
#      Unnamed: 0         Words  \
# 0           1.0       punting
# 1           NaN           NaN
# 2           2.0         crowd
# 3           NaN           NaN
# 4           3.0        secret
# ..          ...           ...
# 635       448.0     carborane
# 636         NaN           NaN
# 637       449.0  denouncement
# 638         NaN           NaN
# 639       450.0      Columbia
#
#                                                   Type  \
# 0                                               (verb)
# 1                                                  NaN
# 2                                               (noun)
# 3                                                  NaN
# 4                                          (adjective)
# ..                                                 ...
# 635  (noun) any of a class of compounds that are th...
# 636       in the synthesis of lubricants and polymers.
# 637  (noun) the act of making known or declaring so...
# ...

# %%
df_2019.drop('Unnamed: 0', axis=1,inplace=True)
df_2019
# Out:
#             Words                                               Type  \
# 0         punting                                             (verb)
# 1             NaN                                                NaN
# 2           crowd                                             (noun)
# 3             NaN                                                NaN
# 4          secret                                        (adjective)
# ..            ...                                                ...
# 635     carborane  (noun) any of a class of compounds that are th...
# 636           NaN       in the synthesis of lubricants and polymers.
# 637  denouncement  (noun) the act of making known or declaring so...
# 638           NaN                                 people in command.
# 639      Columbia                          (noun) the United States.
#
#                                            Description
# 0    to kick a ball when playing football, soccer o...
# ...

# %%
def Orfind(x):
    
    if x in  'OR ':
        print(x)
df_Words = df_2019.applymap(Orfind)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-8df168a5961b> in <module>
#       3     if x in  'OR ':
#       4         print(x)
# ----> 5 df_Words = df_2019.applymap(Orfind)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in applymap(self, func)
#    6942             return lib.map_infer(x.astype(object).values, func)
#    6943
# -> 6944         return self.apply(infer)
#    6945
#    6946     # ----------------------------------------------------------------------
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
# ...
