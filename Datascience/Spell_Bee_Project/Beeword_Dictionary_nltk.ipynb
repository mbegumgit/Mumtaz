# %%
class sample():
    def __init__(self,x):
        self.word =x
    
    def __str__(self):
        return f"Title case printing : {self.word.title()} "
s1 = sample('hi mumtaz')

print(s1)
# Out:
# Title case printing : Hi Mumtaz

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.corpus import wordnet 
syns1 = wordnet.synsets("quickly")
print("Defination of the said word:")
print(syns1[0].definition())
print("\nExamples of the word in use::")
print(syns1[0].examples())
syns2 = wordnet.synsets("wonderful")
# Out:
# Defination of the said word:
# with rapid movements
#
# Examples of the word in use::
# ['he works quickly']

# %%
print(syns1)
print(syns2)
# Out:
# [Synset('quickly.r.01'), Synset('promptly.r.01'), Synset('cursorily.r.01')]
# [Synset('fantastic.s.02')]

# %%
from nltk.corpus import wordnet as wn
words = ['amazing', 'interesting', 'love', 'great', 'nice']

for w in words:
    tmp = wn.synsets(w)[0].pos()
    print(w, ":", tmp)
# Out:
# amazing : v
# interesting : v
# love : n
# great : n
# nice : n

# %%
import pandas as pd
import numpy as np
import re
Bee_201920_df = pd.read_csv('Bee_Docs/Bee_Word_2019-20.csv',index_col='Index')
from random import sample

# given data frame df

# create random index
rindex =  np.array(sample(range(len(Bee_201920_df)), 10))

# get 10 random rows from df
dfr = Bee_201920_df.index[rindex]

# %%
words_list =Bee_201920_df['Words']
words_list[]
# Out:
# Index
# 0           punting
# 1             crowd
# 2            secret
# 3            fumble
# 4              pond
#            ...
# 451        jodhpurs
# 452     hydrargyrum
# 453       carborane
# 454    denouncement
# 455        Columbia
# Name: Words, Length: 456, dtype: object

# %%
from nltk.corpus import wordnet as wn
import numpy as np

#words_list['Sample_Words'] =Bee_201920_df['Words']

#print('list: ', words_list)
dict_set  = np.array(Bee_201920_df['Words'].apply(lambda w : wn.synsets(w)))
 
dict_set =[x  if x != [] else '##' for x in dict_set ] 
def dict_convert(dict_set):
    dict_type={'v': 'verb','a':'adjective', 'n':'noun','r':'adverb','s': 'noun'}
    x=[]
    for each in dict_set:
        if each != '##':
            x.append(dict_type[each[0].pos()])
        else:
            x.append('subject')
    return np.array(x)
df_type = pd.DataFrame({"Dict_Type": dict_convert(dict_set)})
Bee_201920_df = pd.concat([Bee_201920_df,df_type],ignore_index=True,axis=1)
    #print(each[0].pos())
#    print(type(each[0]))
#    print('word:',w,' word type',dict_type[each[0].pos()])
#print('original type',Bee_201920_df.iloc[dfr,1])

# %%
Bee_201920_df.to_csv('Bee_201920_dict.csv', encoding='utf-8-sig')

# %%
from nltk.corpus import wordnet as wn
dict_type={'v': 'verb','a':'adjective', 'n':'noun','r':'adverb','s': 'subject'}

for w in Bee_201920_df.iloc[dfr,0]:
    tmp = wn.synsets(w)[0].pos()
    
    print('word',w,' word type',dict_type[tmp])
    print('original type',Bee_201920_df.iloc[dfr,1])
from nltk.corpus import wordnet as wn
dict_type={'v': 'verb','a':'adjective', 'n':'noun','r':'adverb','s': 'noun'}
#words_list =np.array(Bee_201920_df.iloc[dfr,0])
words_list=['profound', 'culminate', 'remarkable', 'grub', 'arrange','opportunity', 'social', 'haughty', 'teak', 'carborane']
def word_find(w):
    return wn.synsets(w)

dictset=[]    
for w in words_list:
    dictset.append(word_find(w))

dictset =[x for x in dictset or '' or [] if x  ]# dropping None or empty values
    
    #print(each[0].pos())
#    print(type(each[0]))
    print('word:',w,' word type',dict_type[each[0].pos()])
#print('original type',Bee_201920_df.iloc[dfr,1])
# Out:
# word profound  word type adjective
# original type Index
# 206    adjective
# 383         verb
# 301    adjective
# 70          noun
# 282         verb
# 411         noun
# 87     adjective
# 409    adjective
# 155         noun
# 453         noun
# Name: Type, dtype: object
# word culminate  word type verb
# original type Index
# 206    adjective
# 383         verb
# 301    adjective
# 70          noun
# 282         verb
# 411         noun
# 87     adjective
# 409    adjective
# 155         noun
# 453         noun
# Name: Type, dtype: object
# word remarkable  word type subject
# original type Index
# 206    adjective
# 383         verb
# 301    adjective
# 70          noun
# 282         verb
# 411         noun
# 87     adjective
# 409    adjective
# 155         noun
# 453         noun
# Name: Type, dtype: object
# word grub  word type noun
# original type Index
# 206    adjective
# 383         verb
# 301    adjective
# 70          noun
# 282         verb
# 411         noun
# 87     adjective
# 409    adjective
# 155         noun
# 453         noun
# Name: Type, dtype: object
# word arrange  word type verb
# original type Index
# 206    adjective
# 383         verb
# 301    adjective
# 70          noun
# 282         verb
# 411         noun
# 87     adjective
# 409    adjective
# 155         noun
# 453         noun
# Name: Type, dtype: object
# word opportunity  word type noun
# original type Index
# 206    adjective
# 383         verb
# 301    adjective
# 70          noun
# 282         verb
# 411         noun
# 87     adjective
# 409    adjective
# 155         noun
# 453         noun
# Name: Type, dtype: object
# word social  word type noun
# original type Index
# 206    adjective
# 383         verb
# 301    adjective
# 70          noun
# 282         verb
# 411         noun
# 87     adjective
# 409    adjective
# 155         noun
# 453         noun
# Name: Type, dtype: object
# word haughty  word type subject
# original type Index
# 206    adjective
# 383         verb
# 301    adjective
# 70          noun
# 282         verb
# 411         noun
# 87     adjective
# 409    adjective
# 155         noun
# 453         noun
# Name: Type, dtype: object
# word teak  word type noun
# original type Index
# 206    adjective
# 383         verb
# 301    adjective
# 70          noun
# 282         verb
# 411         noun
# 87     adjective
# 409    adjective
# 155         noun
# 453         noun
# Name: Type, dtype: object
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-1734c9d58c16> in <module>
#       3
#       4 for w in Bee_201920_df.iloc[dfr,0]:
# ----> 5     tmp = wn.synsets(w)[0].pos()
#       6
#       7     print('word',w,' word type',dict_type[tmp])
#
# IndexError: list index out of range

# %%
dictset = np.array(dict_set)
dictset =[x  if x != [] else '##' for x in dictset ]
dictset
#dict_set1.to_csv('dict_set.csv')
# Out:
# [[Synset('punt.n.03'),
#   Synset('punt.v.01'),
#   Synset('punt.v.02'),
#   Synset('bet_on.v.01')],
#  [Synset('crowd.n.01'),
#   Synset('crowd.n.02'),
#   Synset('herd.v.01'),
#   Synset('crowd.v.02'),
#   Synset('crowd.v.03'),
#   Synset('push.v.06')],
#  [Synset('secret.n.01'),
#   Synset('secret.n.02'),
#   Synset('mystery.n.01'),
#   Synset('secret.s.01'),
#   Synset('clandestine.s.01'),
#   Synset('unavowed.s.03'),
#   Synset('secret.s.04'),
#   Synset('secret.s.05'),
#   Synset('hidden.s.02'),
#   Synset('privy.s.01'),
#   Synset('confidential.s.02'),
#   Synset('secret.s.09'),
#   Synset('mysterious.s.02'),
#   Synset('secret.s.11')],
#  [Synset('fumble.n.01'),
#   Synset('grope.v.01'),
#   Synset('fumble.v.02'),
#   Synset('fumble.v.03'),
#   Synset('botch.v.01'),
#   Synset('fumble.v.05')],
#  [Synset('pond.n.01')],
#  [Synset('health.n.01'), Synset('health.n.02')],
#  [Synset('forgiveness.n.02'),
#   Synset('pardon.n.02'),
#   Synset('amnesty.n.03'),
#   Synset('excuse.v.01'),
#   Synset('pardon.v.02')],
#  [Synset('shingle.n.01'),
#   Synset('milkshake.n.01'),
#   Synset('trill.n.01'),
#   Synset('handshake.n.01'),
#   Synset('tremble.n.01'),
#   Synset('wag.n.02'),
#   Synset('shake.v.01'),
#   Synset('shake.v.02'),
#   Synset('judder.v.01'),
#   Synset('rock.v.01'),
#   Synset('shake.v.05'),
#   Synset('stimulate.v.03'),
#   Synset('shake.v.07'),
#   Synset('shake.v.08'),
#   Synset('shake.v.09')],
#  '##',
#  [Synset('proof.n.01'),
#   Synset('proof.n.02'),
#   Synset('proof.n.03'),
#   Synset('proof.n.04'),
#   Synset('proof.n.05'),
#   Synset('validation.n.01'),
#   Synset('proof.v.01'),
#   Synset('proof.v.02'),
#   Synset('proofread.v.01'),
#   Synset('proof.v.04'),
#   Synset('proof.v.05'),
#   Synset('proof.s.01')],
#  '##',
#  [Synset('town.n.01'),
#   Synset('town.n.02'),
#   Synset('township.n.01'),
#   Synset('town.n.04')],
#  [Synset('lotto.n.01')],
#  [Synset('cagey.s.01'), Synset('apt.s.03'), Synset('clever.s.03')],
#  [Synset('inside.n.01'),
#   Synset('inside.n.02'),
#   Synset('inside.a.01'),
#   Synset('inside.s.02'),
#   Synset('inside.s.03'),
#   Synset('inside.s.04'),
#   Synset('inside.r.01'),
#   Synset('inside.r.02'),
#   Synset('inwardly.r.01'),
#   Synset('at_heart.r.01')],
#  [Synset('answer.n.01'), Synset('reply.n.02'), Synset('answer.v.01')],
#  [Synset('freeze.v.01'),
#   Synset('freeze.v.02'),
#   Synset('freeze.v.03'),
#   Synset('freeze.v.04'),
#   Synset('freeze.v.05'),
#   Synset('freeze.v.06'),
#   Synset('freeze.v.07'),
#   Synset('freeze.v.08'),
#   Synset('freeze.v.09'),
#   Synset('freeze.v.10'),
#   Synset('frozen.a.01'),
#   Synset('frozen.s.02'),
#   Synset('frigid.s.03'),
#   Synset('frozen.s.04'),
#   Synset('flash-frozen.s.01'),
#   Synset('frozen.s.06'),
#   Synset('fixed.s.04')],
#  [Synset('special.n.01'),
#   Synset('special.n.02'),
#   Synset('special.n.03'),
#   Synset('particular.s.01'),
#   Synset('special.s.02'),
#   Synset('especial.s.01'),
#   Synset('special.s.04'),
#   Synset('limited.s.06'),
#   Synset('particular.s.04'),
#   Synset('extra.s.02')],
#  [Synset('movie.n.01'),
#   Synset('film.n.02'),
#   Synset('film.n.03'),
#   Synset('film.n.04'),
#   Synset('film.n.05'),
#   Synset('film.v.01'),
#   Synset('film.v.02')],
#  [Synset('consequence.n.01'),
#   Synset('solution.n.02'),
#   Synset('result.n.03'),
#   Synset('resultant_role.n.01'),
#   Synset('result.v.01'),
#   Synset('leave.v.07'),
#   Synset('result.v.03')],
#  [Synset('sodium_carbonate.n.01'), Synset('pop.n.02')],
#  [Synset('sealing_wax.n.01'),
#   Synset('seal.n.02'),
#   Synset('seal.n.03'),
#   Synset('navy_seal.n.01'),
#   Synset('seal.n.05'),
#   Synset('cachet.n.01'),
#   Synset('seal.n.07'),
#   Synset('seal.n.08'),
#   Synset('seal.n.09'),
#   Synset('seal.v.01'),
#   Synset('seal.v.02'),
#   Synset('seal.v.03'),
#   Synset('seal.v.04'),
#   Synset('varnish.v.01'),
#   Synset('seal.v.06')],
#  [Synset('twirl.v.01'), Synset('whirl.v.02')],
#  [Synset('disembark.v.01')],
#  [Synset('admit.v.01'),
#   Synset('admit.v.02'),
#   Synset('admit.v.03'),
#   Synset('accept.v.05'),
#   Synset('admit.v.05'),
#   Synset('admit.v.06'),
#   Synset('accommodate.v.04'),
#   Synset('admit.v.08')],
#  '##',
#  [Synset('piece.n.01'),
#   Synset('piece.n.02'),
#   Synset('part.n.03'),
#   Synset('musical_composition.n.01'),
#   Synset('piece.n.05'),
#   Synset('piece.n.06'),
#   Synset('firearm.n.01'),
#   Synset('piece.n.08'),
#   Synset('piece.n.09'),
#   Synset('objet_d'art.n.01'),
#   Synset('while.n.01'),
#   Synset('slice.n.01'),
#   Synset('man.n.10'),
#   Synset('patch.v.01'),
#   Synset('assemble.v.01'),
#   Synset('piece.v.03'),
#   Synset('nibble.v.03'),
#   Synset('piece.v.05')],
#  [Synset('brass.n.01'),
#   Synset('brass.n.02'),
#   Synset('administration.n.02'),
#   Synset('boldness.n.02'),
#   Synset('brass.n.05'),
#   Synset('brass_section.n.01'),
#   Synset('brass.n.07')],
#  [Synset('inshore.a.01'), Synset('onshore.s.02'), Synset('onshore.r.01')],
#  [Synset('stunt.n.01'),
#   Synset('stunt.n.02'),
#   Synset('stunt.v.01'),
#   Synset('stunt.v.02')],
#  [Synset('deny.v.01'),
#   Synset('deny.v.02'),
#   Synset('deny.v.03'),
#   Synset('deny.v.04'),
#   Synset('deny.v.05'),
#   Synset('traverse.v.03'),
#   Synset('deny.v.07')],
#  [Synset('jolly.n.01'),
#   Synset('jolly_boat.n.01'),
#   Synset('kid.v.02'),
#   Synset('gay.s.02'),
#   Synset('reasonably.r.01')],
#  [Synset('powder.n.01'),
#   Synset('gunpowder.n.01'),
#   Synset('powder.n.03'),
#   Synset('powderize.v.02'),
#   Synset('powder.v.02')],
#  [Synset('earthquake.n.01'), Synset('earthquake.n.02')],
#  [Synset('walnut.n.01'), Synset('walnut.n.02'), Synset('walnut.n.03')],
#  [Synset('sawdust.n.01')],
#  [Synset('fluster.v.01'), Synset('fluster.v.02'), Synset('flustered.s.01')],
#  [Synset('barber.n.01'), Synset('barber.n.02'), Synset('barber.v.01')],
#  [Synset('chime.n.01'), Synset('chime.v.01')],
#  [Synset('cabin.n.01'),
#   Synset('cabin.n.02'),
#   Synset('cabin.n.03'),
#   Synset('cabin.v.01')],
#  [Synset('faint.n.01'),
#   Synset('faint.v.01'),
#   Synset('faint.s.01'),
#   Synset('dim.s.02'),
#   Synset('faint.s.03'),
#   Synset('faint.s.04'),
#   Synset('faint.s.05'),
#   Synset('faint.s.06')],
#  [Synset('manger.n.01')],
#  [Synset('peppermint.n.01'),
#   Synset('red_gum.n.03'),
#   Synset('peppermint.n.03')],
#  [Synset('broth.n.01'), Synset('broth.n.02')],
#  [Synset('ash.n.01'),
#   Synset('ash.n.02'),
#   Synset('ash.n.03'),
#   Synset('ash.v.01')],
#  [Synset('fire.n.03'),
#   Synset('flare.v.03'),
#   Synset('flame.v.02'),
#   Synset('flame.v.03')],
#  [Synset('grits.n.01'),
#   Synset('grit.n.01'),
#   Synset('backbone.n.02'),
#   Synset('grit.v.01'),
#   Synset('grit.v.02')],
#  [Synset('cliff.n.01')],
#  [Synset('hem.n.01'),
#   Synset('hem.n.02'),
#   Synset('hem.v.01'),
#   Synset('hem.v.02')],
#  [Synset('candle.n.01'), Synset('candle.n.02'), Synset('candle.v.01')],
#  [Synset('brim.n.01'),
#   Synset('brim.n.02'),
#   Synset('brim.v.01'),
#   Synset('brim.v.02')],
#  [Synset('plot.n.01'),
#   Synset('plot.n.02'),
#   Synset('plot.n.03'),
#   Synset('plot.n.04'),
#   Synset('plot.v.01'),
#   Synset('diagram.v.01'),
#   Synset('plat.v.01'),
#   Synset('plot.v.04')],
#  [Synset('desk.n.01')],
#  [Synset('bobcat.n.01')],
#  [Synset('polo.n.01'), Synset('polo.n.02')],
#  [Synset('roller.n.01'),
#   Synset('roller.n.02'),
#   Synset('roller.n.03'),
#   Synset('roller.n.04'),
#   Synset('curler.n.01'),
#   Synset('roller.n.06'),
#   Synset('roller.n.07')],
#  [Synset('blunt.s.04'),
#   Synset('austere.s.01'),
#   Synset('stark.s.03'),
#   Synset('arrant.s.01'),
#   Synset('bare.s.08'),
#   Synset('stark.r.01')],
#  [Synset('drum.n.01'),
#   Synset('drum.n.02'),
#   Synset('barrel.n.03'),
#   Synset('drum.n.04'),
#   Synset('brake_drum.n.01'),
#   Synset('drum.n.06'),
#   Synset('drum.v.01'),
#   Synset('drum.v.02'),
#   Synset('cram.v.03')],
#  [Synset('snarl.n.01'),
#   Synset('snarl.n.02'),
#   Synset('tangle.n.02'),
#   Synset('snap.v.01'),
#   Synset('snarl.v.02'),
#   Synset('entangle.v.02'),
#   Synset('snarl.v.04')],
#  [Synset('argue.v.01'), Synset('argue.v.02'), Synset('argue.v.03')],
#  [Synset('pruner.n.02')],
#  [Synset('petal.n.01')],
#  [Synset('giant.n.01'),
#   Synset('colossus.n.02'),
#   Synset('giant.n.03'),
#   Synset('giant.n.04'),
#   Synset('giant.n.05'),
#   Synset('giant.n.06'),
#   Synset('giant_star.n.01'),
#   Synset('elephantine.s.01')],
#  [Synset('snuffle.n.01'), Synset('snivel.v.03'), Synset('sniff.v.02')],
#  [Synset('mouth.n.01'),
#   Synset('mouth.n.02'),
#   Synset('mouth.n.03'),
#   Synset('mouth.n.04'),
#   Synset('mouth.n.05'),
#   Synset('mouthpiece.n.03'),
#   Synset('sass.n.01'),
#   Synset('mouth.n.08'),
#   Synset('talk.v.02'),
#   Synset('mouth.v.02'),
#   Synset('mouth.v.03')],
#  [Synset('filter.n.01'),
#   Synset('filter.n.02'),
#   Synset('filter.v.01'),
#   Synset('percolate.v.05'),
#   Synset('trickle.v.01')],
#  [Synset('cone.n.01'),
#   Synset('cone.n.02'),
#   Synset('cone.n.03'),
#   Synset('cone.n.04'),
#   Synset('cone.v.01')],
#  [Synset('never.r.01'), Synset('never.r.02')],
#  [Synset('silly.n.01'),
#   Synset('cockamamie.s.01'),
#   Synset('airheaded.s.01'),
#   Synset('pathetic.s.03'),
#   Synset('punch-drunk.s.01')],
#  [Synset('monday.n.01')],
#  [Synset('chow.n.02'),
#   Synset('grub.n.02'),
#   Synset('mooch.v.01'),
#   Synset('grub.v.02')],
#  [Synset('hook.n.01'),
#   Synset('hook.n.02'),
#   Synset('bait.n.01'),
#   Synset('hook.n.04'),
#   Synset('hook.n.05'),
#   Synset('hook.n.06'),
#   Synset('hook.n.07'),
#   Synset('hook_shot.n.01'),
#   Synset('hook.v.01'),
#   Synset('overcharge.v.01'),
#   Synset('crochet.v.02'),
#   Synset('hook.v.04'),
#   Synset('hook.v.05'),
#   Synset('pilfer.v.01'),
#   Synset('hook.v.07'),
#   Synset('hook.v.08'),
#   Synset('addict.v.01'),
#   Synset('hook.v.10'),
#   Synset('hook.v.11'),
#   Synset('hook.v.12')],
#  [Synset('number.n.01'),
#   Synset('number.n.02'),
#   Synset('act.n.04'),
#   Synset('phone_number.n.01'),
#   Synset('numeral.n.01'),
#   Synset('issue.n.02'),
#   Synset('number.n.07'),
#   Synset('number.n.08'),
#   Synset('number.n.09'),
#   Synset('number.n.10'),
#   Synset('number.n.11'),
#   Synset('total.v.01'),
#   Synset('number.v.02'),
#   Synset('number.v.03'),
#   Synset('count.v.05'),
#   Synset('count.v.01'),
#   Synset('number.v.06')],
#  [Synset('cooking.n.01'),
#   Synset('cook.v.01'),
#   Synset('cook.v.02'),
#   Synset('cook.v.03'),
#   Synset('fudge.v.01'),
#   Synset('cook.v.05')],
#  [Synset('amaze.v.01'), Synset('perplex.v.01'), Synset('amazed.s.01')],
#  [Synset('collect.n.01'),
#   Synset('roll_up.v.02'),
#   Synset('collect.v.02'),
#   Synset('gather.v.01'),
#   Synset('collect.v.04'),
#   Synset('collect.v.05'),
#   Synset('collect.s.01'),
#   Synset('collect.r.01')],
#  [Synset('local.n.01'),
#   Synset('local_anesthetic.n.01'),
#   Synset('local.a.01'),
#   Synset('local.a.02'),
#   Synset('local.a.03')],
#  [Synset('proper.a.01'),
#   Synset('proper.s.02'),
#   Synset('proper.s.03'),
#   Synset('proper.s.04')],
#  [Synset('basement.n.01'), Synset('basement.n.02')],
#  [Synset('ripple.n.01'),
#   Synset('ripple.n.02'),
#   Synset('ripple.v.01'),
#   Synset('ripple.v.02')],
#  [Synset('feat.n.01')],
#  [Synset('plumbing.n.01'),
#   Synset('plumbing.n.02'),
#   Synset('bathymetry.n.01'),
#   Synset('plumb.v.01'),
#   Synset('plumb.v.02'),
#   Synset('plumb.v.03'),
#   Synset('plumb.v.04')],
#  [Synset('stubborn.a.01'), Synset('refractory.s.01')],
#  [Synset('adrift.s.01'),
#   Synset('adrift.s.02'),
#   Synset('adrift.r.01'),
#   Synset('adrift.r.02')],
#  [Synset('sweeten.v.01'), Synset('sweeten.v.02')],
#  [Synset('neon.n.01')],
#  [Synset('beeswax.n.01'), Synset('beeswax.v.01')],
#  [Synset('sociable.n.01'),
#   Synset('social.a.01'),
#   Synset('social.a.02'),
#   Synset('social.a.03'),
#   Synset('social.s.04'),
#   Synset('social.s.05'),
#   Synset('social.s.06')],
#  [Synset('behold.v.01')],
#  [Synset('mix.n.01'),
#   Synset('mix.n.02'),
#   Synset('mix.n.03'),
#   Synset('blend.v.03'),
#   Synset('desegregate.v.01'),
#   Synset('mix.v.03'),
#   Synset('mix.v.04'),
#   Synset('mix.v.05'),
#   Synset('shuffle.v.03')],
#  [Synset('baloney.n.01'),
#   Synset('drool.n.02'),
#   Synset('salivate.v.02'),
#   Synset('drivel.v.01')],
#  [Synset('understand.v.01'),
#   Synset('understand.v.02'),
#   Synset('understand.v.03'),
#   Synset('understand.v.04'),
#   Synset('sympathize.v.02')],
#  [Synset('bring.v.01'),
#   Synset('bring.v.02'),
#   Synset('bring.v.03'),
#   Synset('bring.v.04'),
#   Synset('bring.v.05'),
#   Synset('bring.v.06'),
#   Synset('institute.v.02'),
#   Synset('lend.v.01'),
#   Synset('fetch.v.02'),
#   Synset('bring.v.10'),
#   Synset('bring.v.11')],
#  [Synset('sound.n.01'),
#   Synset('sound.n.02'),
#   Synset('sound.n.03'),
#   Synset('sound.n.04'),
#   Synset('audio.n.01'),
#   Synset('phone.n.02'),
#   Synset('strait.n.01'),
#   Synset('sound.n.08'),
#   Synset('sound.v.01'),
#   Synset('sound.v.02'),
#   Synset('sound.v.03'),
#   Synset('sound.v.04'),
#   Synset('voice.v.02'),
#   Synset('sound.v.06'),
#   Synset('fathom.v.02'),
#   Synset('sound.a.01'),
#   Synset('healthy.s.04'),
#   Synset('sound.a.03'),
#   Synset('good.s.17'),
#   Synset('reasoned.s.01'),
#   Synset('legal.s.03'),
#   Synset('sound.s.07'),
#   Synset('heavy.s.26'),
#   Synset('sound.s.09')],
#  [Synset('bench.n.01'),
#   Synset('terrace.n.02'),
#   Synset('judiciary.n.01'),
#   Synset('workbench.n.01'),
#   Synset('bench.n.05'),
#   Synset('bench.n.06'),
#   Synset('bench.n.07'),
#   Synset('bench.v.01'),
#   Synset('bench.v.02')],
#  [Synset('shrug.v.01')],
#  [Synset('still.n.01'),
#   Synset('hush.n.01'),
#   Synset('still.n.03'),
#   Synset('distillery.n.01'),
#   Synset('calm.v.01'),
#   Synset('hush.v.02'),
#   Synset('still.v.03'),
#   Synset('still.v.04'),
#   Synset('inactive.s.10'),
#   Synset('silent.s.01'),
#   Synset('placid.s.01'),
#   Synset('still.a.04'),
#   Synset('still.a.05'),
#   Synset('still.s.06'),
#   Synset('still.r.01'),
#   Synset('however.r.01'),
#   Synset('even.r.03'),
#   Synset('still.r.04')],
#  [Synset('buffoonery.n.01'),
#   Synset('antic.n.01'),
#   Synset('prank.v.01'),
#   Synset('prank.v.02')],
#  [Synset('smile.v.01'), Synset('smile.v.02')],
#  [Synset('peach.n.01'),
#   Synset('smasher.n.02'),
#   Synset('peach.n.03'),
#   Synset('yellowish_pink.n.01'),
#   Synset('spill_the_beans.v.01')],
#  [Synset('pie.n.01'), Synset('proto-indo_european.n.01')],
#  [Synset('size.n.01'),
#   Synset('size.n.02'),
#   Synset('size.n.03'),
#   Synset('size.n.04'),
#   Synset('size.n.05'),
#   Synset('size.v.01'),
#   Synset('size.v.02'),
#   Synset('size.v.03'),
#   Synset('size.s.01')],
#  [Synset('hallway.n.01'),
#   Synset('anteroom.n.01'),
#   Synset('hall.n.03'),
#   Synset('dormitory.n.01'),
#   Synset('manor_hall.n.01'),
#   Synset('hall.n.06'),
#   Synset('hall.n.07'),
#   Synset('hall.n.08'),
#   Synset('hall.n.09'),
#   Synset('hall.n.10'),
#   Synset('mansion.n.02'),
#   Synset('hall.n.12'),
#   Synset('hall.n.13')],
#  [Synset('jingle.v.01')],
#  [Synset('chain.n.01'),
#   Synset('chain.n.02'),
#   Synset('chain.n.03'),
#   Synset('chain.n.04'),
#   Synset('chain.n.05'),
#   Synset('chain.n.06'),
#   Synset('chain.n.07'),
#   Synset('range.n.04'),
#   Synset('chain.n.09'),
#   Synset('chain.n.10'),
#   Synset('chain.v.01'),
#   Synset('chain.v.02')],
#  [Synset('workhorse.n.01'), Synset('workhorse.n.02')],
#  [Synset('antenna.n.01'), Synset('antenna.n.02'), Synset('antenna.n.03')],
#  [Synset('honest.a.01'),
#   Synset('honest.s.02'),
#   Synset('dependable.s.02'),
#   Synset('honest.s.04'),
#   Synset('honest.s.05'),
#   Synset('good.s.19'),
#   Synset('honest.s.07')],
#  [Synset('bellow.n.01'),
#   Synset('hollow.n.02'),
#   Synset('holler.v.01'),
#   Synset('shout.v.02'),
#   Synset('gripe.v.01')],
#  [Synset('billboard.n.01')],
#  [Synset('chicken.n.01'),
#   Synset('chicken.n.02'),
#   Synset('wimp.n.01'),
#   Synset('chicken.n.04'),
#   Synset('chicken.s.01')],
#  [Synset('puppet.n.01'), Synset('creature.n.03'), Synset('puppet.n.03')],
#  [Synset('wait.v.01'),
#   Synset('wait.v.02'),
#   Synset('expect.v.03'),
#   Synset('wait.v.04')],
#  [Synset('coating.n.02'),
#   Synset('stopping_point.n.01'),
#   Synset('polish.n.02'),
#   Synset('finish.n.04'),
#   Synset('finish.n.05'),
#   Synset('finish.n.06'),
#   Synset('ending.n.04'),
#   Synset('finish.n.08'),
#   Synset('finish.n.09'),
#   Synset('complete.v.01'),
#   Synset('finish_up.v.02'),
#   Synset('end.v.01'),
#   Synset('finish.v.04'),
#   Synset('eat_up.v.01'),
#   Synset('finish.v.06')],
#  [Synset('cheer.n.01'),
#   Synset('cheerfulness.n.01'),
#   Synset('cheer.v.01'),
#   Synset('cheer.v.02'),
#   Synset('cheer.v.03'),
#   Synset('cheer.v.04'),
#   Synset('cheer.v.05')],
#  [Synset('tortuous.s.02')],
#  [Synset('french_fries.n.01'),
#   Synset('bit.n.02'),
#   Synset('chip.n.02'),
#   Synset('chip.n.03'),
#   Synset('chip.n.04'),
#   Synset('check.n.09'),
#   Synset('chip.n.06'),
#   Synset('chip.n.07'),
#   Synset('chip.n.08'),
#   Synset('chip.n.09'),
#   Synset('chip.v.01'),
#   Synset('nick.v.02'),
#   Synset('chip.v.03'),
#   Synset('chip.v.04'),
#   Synset('chip.v.05')],
#  [Synset('scoop.n.01'),
#   Synset('scoop.n.02'),
#   Synset('exclusive.n.01'),
#   Synset('soap.n.03'),
#   Synset('scoop.n.05'),
#   Synset('scoop.n.06'),
#   Synset('scoop.v.01'),
#   Synset('outdo.v.02')],
#  [Synset('wanderer.n.01'), Synset('rover.n.02')],
#  [Synset('forgive.v.01'), Synset('forgive.v.02')],
#  [Synset('ribbon.n.01'),
#   Synset('decoration.n.02'),
#   Synset('ribbon.n.03'),
#   Synset('ribbon.n.04')],
#  [Synset('shoo_off.v.01')],
#  [Synset('avaricious.s.01'), Synset('avid.s.01'), Synset('greedy.s.03')],
#  [Synset('radio_beam.n.01'),
#   Synset('beam.n.02'),
#   Synset('beam.n.03'),
#   Synset('beam.n.04'),
#   Synset('beam.n.05'),
#   Synset('beam.n.06'),
#   Synset('balance_beam.n.01'),
#   Synset('beam.v.01'),
#   Synset('shine.v.02'),
#   Synset('beam.v.03'),
#   Synset('air.v.03'),
#   Synset('glow.v.02'),
#   Synset('glow.v.05')],
#  [Synset('crew.n.01'),
#   Synset('gang.n.03'),
#   Synset('crowd.n.02'),
#   Synset('crew.n.04'),
#   Synset('crew.v.01')],
#  [Synset('crate.n.01'), Synset('crate.n.02'), Synset('crate.v.01')],
#  [Synset('hotel.n.01')],
#  [Synset('stray.n.01'),
#   Synset('roll.v.12'),
#   Synset('stray.v.02'),
#   Synset('digress.v.01'),
#   Synset('isolated.s.01'),
#   Synset('stray.s.02')],
#  [Synset('gallop.n.01'),
#   Synset('gallop.v.01'),
#   Synset('gallop.v.02'),
#   Synset('gallop.v.03')],
#  [Synset('dinosaur.n.01')],
#  [Synset('ancient.n.01'),
#   Synset('ancient.n.02'),
#   Synset('ancient.s.01'),
#   Synset('ancient.s.02')],
#  [Synset('tapestry.n.01'), Synset('tapestry.n.02'), Synset('tapestry.n.03')],
#  [Synset('delivery.n.01'),
#   Synset('delivery.n.02'),
#   Synset('manner_of_speaking.n.01'),
#   Synset('delivery.n.04'),
#   Synset('pitch.n.02'),
#   Synset('rescue.n.01'),
#   Synset('delivery.n.07')],
#  '##',
#  [Synset('salamander.n.01'), Synset('salamander.n.02'), Synset('poker.n.01')],
#  [Synset('usual.a.01'), Synset('common.s.04')],
#  [Synset('challenge.n.01'),
#   Synset('challenge.n.02'),
#   Synset('challenge.n.03'),
#   Synset('challenge.n.04'),
#   Synset('challenge.n.05'),
#   Synset('challenge.v.01'),
#   Synset('challenge.v.02'),
#   Synset('challenge.v.03'),
#   Synset('challenge.v.04')],
#  [Synset('cahoot.n.01')],
#  [Synset('seepage.n.01'),
#   Synset('seep.v.01'),
#   Synset('exude.v.01'),
#   Synset('oozing.s.01')],
#  [Synset('mars.n.01'),
#   Synset('mars.n.02'),
#   Synset('march.n.01'),
#   Synset('blemish.n.01'),
#   Synset('mar.v.01'),
#   Synset('mutilate.v.03')],
#  [Synset('pelican.n.01')],
#  [Synset('drastic.s.01')],
#  [Synset('yoga.n.01'), Synset('yoga.n.02')],
#  [Synset('burlap.n.01')],
#  [Synset('blazer.n.01')],
#  [Synset('trombone.n.01')],
#  [Synset('shaking.n.02'), Synset('tremble.v.01'), Synset('shaky.s.02')],
#  [Synset('calm.v.01'),
#   Synset('steady.v.01'),
#   Synset('calm.v.03'),
#   Synset('sedate.v.01')],
#  [Synset('police.n.01'), Synset('patrol.v.01')],
#  [Synset('certain.s.01'),
#   Synset('certain.a.02'),
#   Synset('certain.a.03'),
#   Synset('certain.a.04'),
#   Synset('sealed.a.01'),
#   Synset('certain.s.06'),
#   Synset('certain.s.07')],
#  [Synset('barograph.n.01')],
#  [Synset('char.v.01'), Synset('char.v.02')],
#  [Synset('pakistan.n.01')],
#  [Synset('pressure.n.01'),
#   Synset('pressure.n.02'),
#   Synset('press.n.09'),
#   Synset('imperativeness.n.01'),
#   Synset('pressure.n.05'),
#   Synset('pressure.n.06'),
#   Synset('atmospheric_pressure.n.01'),
#   Synset('coerce.v.01'),
#   Synset('blackmail.v.01')],
#  [Synset('surmise.v.01'), Synset('suspect.v.01')],
#  [Synset('teak.n.01'), Synset('teak.n.02')],
#  [Synset('theodolite.n.01'),
#   Synset('transportation_system.n.01'),
#   Synset('passage.n.05'),
#   Synset('transit.v.01'),
#   Synset('transit.v.02'),
#   Synset('transit.v.03'),
#   Synset('transit.v.04')],
#  [Synset('cannonade.n.01'), Synset('cannonade.v.01')],
#  [Synset('appetite.n.01')],
#  [Synset('baggage.n.01')],
#  [Synset('rampart.n.01')],
#  [Synset('vinyl.n.01'), Synset('vinyl.n.02')],
#  [Synset('anemometer.n.01')],
#  [Synset('dainty.n.01'),
#   Synset('dainty.s.01'),
#   Synset('dainty.s.02'),
#   Synset('dainty.s.03'),
#   Synset('dainty.s.04')],
#  [Synset('buckle.n.01'),
#   Synset('warp.n.02'),
#   Synset('buckle.v.01'),
#   Synset('buckle.v.02'),
#   Synset('heave.v.07')],
#  [Synset('vividly.r.01')],
#  [Synset('main.n.01'), Synset('brackish.s.02')],
#  [Synset('pavement.n.01'), Synset('paving.n.01'), Synset('sidewalk.n.01')],
#  [Synset('garnet.n.01')],
#  [Synset('furrow.n.01'),
#   Synset('wrinkle.n.01'),
#   Synset('furrow.v.01'),
#   Synset('furrow.v.02'),
#   Synset('furrow.v.03')],
#  [Synset('conurbation.n.01'),
#   Synset('sprawl.n.02'),
#   Synset('sprawl.v.01'),
#   Synset('sprawl.v.02')],
#  [Synset('museum.n.01')],
#  [Synset('wren.n.01'), Synset('wren.n.02')],
#  [Synset('legend.n.01'), Synset('caption.n.03')],
#  [Synset('transistor.n.01')],
#  [Synset('magnify.v.01'),
#   Synset('overstate.v.01'),
#   Synset('inflate.v.01'),
#   Synset('amplify.v.04')],
#  [Synset('security.n.01'),
#   Synset('security.n.02'),
#   Synset('security.n.03'),
#   Synset('security.n.04'),
#   Synset('security.n.05'),
#   Synset('security.n.06'),
#   Synset('security.n.07'),
#   Synset('security_system.n.02'),
#   Synset('security.n.09')],
#  [Synset('refrain.n.01'), Synset('refrain.v.01'), Synset('abstain.v.02')],
#  [Synset('tactics.n.01'), Synset('tactic.n.01'), Synset('tactic.n.01')],
#  [Synset('shepherd.n.01'),
#   Synset('sheepherder.n.01'),
#   Synset('shepherd.v.01'),
#   Synset('shepherd.v.02')],
#  [Synset('angus_og.n.01'), Synset('aberdeen_angus.n.01')],
#  [Synset('hardheaded.s.01')],
#  [Synset('competition.n.03')],
#  [Synset('sibling.n.01')],
#  [Synset('chestnut.n.01'),
#   Synset('chestnut.n.02'),
#   Synset('chestnut.n.03'),
#   Synset('chestnut.n.04'),
#   Synset('chestnut.n.05'),
#   Synset('chestnut.n.06'),
#   Synset('chestnut.s.01')],
#  [Synset('minivan.n.01')],
#  [Synset('tartan.n.01')],
#  [Synset('tissue.n.01'), Synset('tissue.n.02'), Synset('weave.v.02')],
#  [Synset('villain.n.01')],
#  [Synset('amino.n.01'), Synset('amino.a.01')],
#  [Synset('menthol.n.01'), Synset('menthol.n.02')],
#  [Synset('tabasco.n.01'), Synset('tabasco.n.02'), Synset('tabasco.n.03')],
#  [Synset('obvious.a.01')],
#  [Synset('pulsation.n.01'),
#   Synset('pulse.n.02'),
#   Synset('pulse.n.03'),
#   Synset('pulse.n.04'),
#   Synset('pulsate.v.01'),
#   Synset('pulse.v.02'),
#   Synset('pulse.v.03')],
#  [Synset('bungalow.n.01')],
#  [Synset('garland.n.01'),
#   Synset('garland.n.02'),
#   Synset('florilegium.n.01'),
#   Synset('wreath.n.01'),
#   Synset('garland.v.01')],
#  [Synset('gnaw.v.01'), Synset('erode.v.01')],
#  [Synset('comfort.n.01'),
#   Synset('comfort.n.02'),
#   Synset('consolation.n.02'),
#   Synset('ease.n.02'),
#   Synset('comfort.n.05'),
#   Synset('quilt.n.01'),
#   Synset('comfort.n.07'),
#   Synset('comfort.v.01'),
#   Synset('comfort.v.02')],
#  [Synset('caroling.n.01'), Synset('carol.v.01')],
#  [Synset('carol.v.01')],
#  [Synset('folly.n.01'), Synset('folly.n.03'), Synset('stupidity.n.02')],
#  [Synset('configuration.n.01'), Synset('constellation.n.02')],
#  [Synset('sunder.v.01')],
#  [Synset('juncture.n.01'),
#   Synset('juncture.n.02'),
#   Synset('articulation.n.02')],
#  [Synset('feat.n.01'),
#   Synset('exploit.v.01'),
#   Synset('exploit.v.02'),
#   Synset('overwork.v.02')],
#  [Synset('demagogue.n.01')],
#  [Synset('profound.a.01'),
#   Synset('profound.s.02'),
#   Synset('fundamental.s.03'),
#   Synset('profound.s.04'),
#   Synset('heavy.s.26'),
#   Synset('profound.s.06')],
#  [Synset('wreath.n.01')],
#  [Synset('profile.n.01'),
#   Synset('profile.n.02'),
#   Synset('profile.n.03'),
#   Synset('visibility.n.02'),
#   Synset('profile.n.05'),
#   Synset('profile.v.01'),
#   Synset('profile.v.02')],
#  [Synset('indecent.s.01'), Synset('adverse.s.01')],
#  [Synset('memorial.n.01'), Synset('memorial.n.02'), Synset('memorial.n.03')],
#  [Synset('industrial.a.01'),
#   Synset('industrial.a.02'),
#   Synset('industrial.s.03'),
#   Synset('industrial.s.04')],
#  [Synset('barrier.n.01'), Synset('barrier.n.02'), Synset('barrier.n.03')],
#  [Synset('gratingly.r.01')],
#  [Synset('hee-haw.v.01'), Synset('grind.v.05'), Synset('bray.v.03')],
#  [Synset('harlem.n.01')],
#  [Synset('messenger.n.01')],
#  [Synset('beacon.n.01'),
#   Synset('radio_beacon.n.02'),
#   Synset('beacon.n.03'),
#   Synset('beacon.v.01'),
#   Synset('beacon.v.02')],
#  [Synset('coevals.n.01'),
#   Synset('generation.n.02'),
#   Synset('generation.n.03'),
#   Synset('generation.n.04'),
#   Synset('genesis.n.01'),
#   Synset('generation.n.06'),
#   Synset('generation.n.07')],
#  [Synset('coverage.n.01'), Synset('coverage.n.02'), Synset('coverage.n.03')],
#  [Synset('deter.v.01'), Synset('dissuade.v.01')],
#  [Synset('nepal.n.01')],
#  [Synset('disinfectant.n.01'), Synset('bactericidal.s.01')],
#  [Synset('political_campaign.n.01'),
#   Synset('campaign.n.02'),
#   Synset('campaign.n.03'),
#   Synset('campaign.n.04'),
#   Synset('campaign.v.01'),
#   Synset('crusade.v.01'),
#   Synset('campaign.v.03')],
#  [Synset('starvation.n.01'), Synset('starvation.n.02')],
#  [Synset('gamma.n.01'), Synset('gamma.n.02'), Synset('da_gamma.n.01')],
#  [Synset('spleen.n.01'), Synset('irascibility.n.01')],
#  [Synset('utensil.n.01')],
#  [Synset('terminal.n.01'), Synset('storehouse.n.01')],
#  [Synset('incident.n.01'),
#   Synset('incident.n.02'),
#   Synset('incident.a.01'),
#   Synset('incidental.a.01')],
#  [Synset('bramble.n.01')],
#  '##',
#  [Synset('shingle.n.01'),
#   Synset('shingle.n.02'),
#   Synset('shingle.n.03'),
#   Synset('shingle.v.01')],
#  [Synset('mason.n.01'),
#   Synset('mason.n.02'),
#   Synset('mason.n.03'),
#   Synset('mason.n.04'),
#   Synset('freemason.n.01')],
#  [Synset('avoid.v.01'),
#   Synset('debar.v.02'),
#   Synset('avoid.v.03'),
#   Synset('keep_off.v.01'),
#   Synset('invalidate.v.01')],
#  [Synset('static.n.01'),
#   Synset('static.n.02'),
#   Synset('inactive.s.10'),
#   Synset('electrostatic.a.01'),
#   Synset('static.s.03')],
#  [Synset('sample.n.01'),
#   Synset('sample_distribution.n.01'),
#   Synset('sample.n.03'),
#   Synset('sample.v.01')],
#  [Synset('modern.n.01'),
#   Synset('modern.n.02'),
#   Synset('modern.a.01'),
#   Synset('mod.s.01'),
#   Synset('modern.s.03'),
#   Synset('advanced.s.03'),
#   Synset('modern.s.05')],
#  [Synset('chalk.n.01'),
#   Synset('chalk.n.02'),
#   Synset('methamphetamine.n.01'),
#   Synset('chalk.n.04'),
#   Synset('chalk.v.01')],
#  [Synset('dressed_ore.n.01'),
#   Synset('concentrate.n.02'),
#   Synset('concentrate.n.03'),
#   Synset('concentrate.v.01'),
#   Synset('concentrate.v.02'),
#   Synset('centralize.v.01'),
#   Synset('digest.v.07'),
#   Synset('concentrate.v.05'),
#   Synset('condense.v.07'),
#   Synset('boil_down.v.02'),
#   Synset('reduce.v.18')],
#  [Synset('proud.a.01'), Synset('gallant.s.03')],
#  [Synset('termination.n.01'),
#   Synset('passing.n.02'),
#   Synset('exhalation.n.02')],
#  [Synset('battery.n.01'),
#   Synset('battery.n.02'),
#   Synset('battery.n.03'),
#   Synset('battery.n.04'),
#   Synset('battery.n.05'),
#   Synset('barrage.n.02'),
#   Synset('battery.n.07')],
#  [Synset('century.n.01'), Synset('hundred.n.01')],
#  [Synset('differ.v.01'), Synset('disagree.v.01')],
#  [Synset('awful.s.02')],
#  [Synset('ferocious.s.01'),
#   Synset('fierce.s.02'),
#   Synset('cutthroat.s.01'),
#   Synset('boisterous.s.03')],
#  [Synset('residence.n.01'),
#   Synset('residence.n.02'),
#   Synset('residency.n.01'),
#   Synset('mansion.n.02')],
#  [Synset('slake.v.02'), Synset('abate.v.02')],
#  [Synset('scattering.n.01'),
#   Synset('scattering.n.02'),
#   Synset('scattering.n.03'),
#   Synset('dispersion.n.01'),
#   Synset('scatter.n.02'),
#   Synset('disperse.v.02'),
#   Synset('disperse.v.04'),
#   Synset('scatter.v.03'),
#   Synset('scatter.v.04'),
#   Synset('break_up.v.17'),
#   Synset('spread.v.07')],
#  [Synset('tumble.v.01'), Synset('topple.v.02')],
#  [Synset('weathervane.n.01'),
#   Synset('vane.n.02'),
#   Synset('blade.n.08'),
#   Synset('vane.n.04')],
#  [Synset('whirl.n.02'), Synset('whirlpool.n.01')],
#  [Synset('disruptive.s.01'), Synset('churning.s.02')],
#  [Synset('obstacle.n.01'), Synset('obstacle.n.02')],
#  [Synset('continental.a.01'),
#   Synset('continental.a.02'),
#   Synset('continental.a.03'),
#   Synset('continental.a.04')],
#  [Synset('demeanor.n.01')],
#  [Synset('exhibit.n.01'),
#   Synset('display.n.02'),
#   Synset('exhibit.v.01'),
#   Synset('expose.v.03'),
#   Synset('show.v.01'),
#   Synset('parade.v.01')],
#  [Synset('agricultural.a.01'), Synset('agrarian.s.01')],
#  [Synset('momentous.s.01')],
#  [Synset('perturbation.n.03'),
#   Synset('disturbance.n.02'),
#   Synset('disturbance.n.03'),
#   Synset('affray.n.02'),
#   Synset('disturbance.n.05'),
#   Synset('mental_disorder.n.01'),
#   Synset('noise.n.03')],
#  [Synset('crafty.s.01')],
#  [Synset('cub.n.01')],
#  [Synset('transparency.n.01'),
#   Synset('transparency.n.02'),
#   Synset('foil.n.04')],
#  [Synset('hazmat.n.01')],
#  [Synset('antarctic.n.01'), Synset('south-polar.s.01')],
#  [Synset('aroma.n.02'),
#   Synset('perfume.n.02'),
#   Synset('perfume.v.01'),
#   Synset('perfume.v.02')],
#  [Synset('braid.v.01'), Synset('plait.v.02')],
#  [Synset('writer.n.01'), Synset('writer.n.02')],
#  [Synset('series.n.01'),
#   Synset('serial.n.01'),
#   Synset('series.n.03'),
#   Synset('series.n.04'),
#   Synset('series.n.05'),
#   Synset('series.n.06'),
#   Synset('series.n.07')],
#  [Synset('audience.n.01'),
#   Synset('audience.n.02'),
#   Synset('hearing.n.02'),
#   Synset('consultation.n.01')],
#  [Synset('insubstantial.a.01'), Synset('insubstantial.s.02')],
#  [Synset('stagger.v.01'),
#   Synset('stagger.v.02'),
#   Synset('stagger.v.03'),
#   Synset('stagger.v.04')],
#  [Synset('aid.n.02'), Synset('aid.n.01')],
#  [Synset('sanitize.v.01'), Synset('sanitize.v.02'), Synset('sanitized.a.01')],
#  [Synset('decrease.v.01'),
#   Synset('diminish.v.02'),
#   Synset('diminished.s.01'),
#   Synset('atrophied.a.01'),
#   Synset('diminished.s.03'),
#   Synset('belittled.s.01')],
#  [Synset('organist.n.01')],
#  [Synset('operator.n.01'),
#   Synset('operator.n.02'),
#   Synset('operator.n.03'),
#   Synset('hustler.n.02'),
#   Synset('operator.n.05')],
#  [Synset('louisiana.n.01')],
#  [Synset('ageless.s.01'), Synset('ceaseless.s.01')],
#  [Synset('blustering.s.01'), Synset('blustery.s.02')],
#  [Synset('molar.n.01')],
#  [Synset('arrange.v.01'),
#   Synset('arrange.v.02'),
#   Synset('stage.v.02'),
#   Synset('format.v.01'),
#   Synset('dress.v.16'),
#   Synset('arrange.v.06'),
#   Synset('arrange.v.07')],
#  [Synset('dissolve.v.01'),
#   Synset('dissolve.v.02'),
#   Synset('dissolve.v.03'),
#   Synset('disband.v.02'),
#   Synset('dissolve.v.05'),
#   Synset('dissolve.v.06'),
#   Synset('dissolve.v.07'),
#   Synset('dissolve.v.08'),
#   Synset('dissolve.v.09'),
#   Synset('dissolve.v.10'),
#   Synset('dissolve.v.11'),
#   Synset('dissolved.s.01')],
#  [Synset('highly.r.01'), Synset('extremely.r.02')],
#  [Synset('plastic.n.01'),
#   Synset('credit_card.n.01'),
#   Synset('fictile.s.03'),
#   Synset('plastic.s.02'),
#   Synset('formative.s.02')],
#  [Synset('generation.n.07'),
#   Synset('multiplication.n.02'),
#   Synset('multiplication.n.03')],
#  [Synset('center.n.01'),
#   Synset('middle.n.02'),
#   Synset('middle.n.03'),
#   Synset('middle.n.04'),
#   Synset('middle.v.01'),
#   Synset('in-between.s.01'),
#   Synset('center.s.01'),
#   Synset('middle.a.03'),
#   Synset('middle.a.04')],
#  [Synset('reasonable.a.01'), Synset('fair.s.02'), Synset('reasonable.s.03')],
#  [Synset('cupboard.n.01'),
#   Synset('water_closet.n.01'),
#   Synset('wardrobe.n.01'),
#   Synset('closet.n.04'),
#   Synset('closet.v.01')],
#  [Synset('probe.n.01'), Synset('investigation.n.02')],
#  [Synset('accident.n.01'), Synset('accident.n.02')],
#  [Synset('discussion.n.01'), Synset('discussion.n.02')],
#  [Synset('confuse.v.01'),
#   Synset('confuse.v.02'),
#   Synset('confuse.v.03'),
#   Synset('jumble.v.02'),
#   Synset('confuse.v.05'),
#   Synset('baffled.s.01'),
#   Synset('confused.s.02'),
#   Synset('confused.s.03'),
#   Synset('broken.s.08'),
#   Synset('confused.a.05')],
#  [Synset('microwave.n.01'),
#   Synset('microwave.n.02'),
#   Synset('microwave.v.01')],
#  [Synset('gabled.a.01')],
#  [Synset('settle.n.01'),
#   Synset('settle.v.01'),
#   Synset('decide.v.02'),
#   Synset('settle.v.03'),
#   Synset('settle.v.04'),
#   Synset('reconcile.v.03'),
#   Synset('sink.v.04'),
#   Synset('settle.v.07'),
#   Synset('settle.v.08'),
#   Synset('settle.v.09'),
#   Synset('settle.v.10'),
#   Synset('settle.v.11'),
#   Synset('settle.v.12'),
#   Synset('settle.v.13'),
#   Synset('settle.v.14'),
#   Synset('settle.v.15'),
#   Synset('settle.v.16'),
#   Synset('subside.v.03'),
#   Synset('ensconce.v.01'),
#   Synset('settle.v.19'),
#   Synset('finalize.v.01'),
#   Synset('settle.v.21'),
#   Synset('fall.v.32')],
#  [Synset('drab.s.02'), Synset('somber.s.02')],
#  [Synset('drab.s.02'), Synset('somber.s.02')],
#  [Synset('tamper.v.01'), Synset('meddle.v.01')],
#  [Synset('loyal.a.01'), Synset('patriotic.a.01'), Synset('firm.s.10')],
#  [Synset('remarkable.s.01'), Synset('noteworthy.s.02')],
#  [Synset('joist.n.01')],
#  [Synset('scramble.v.01'),
#   Synset('clamber.v.01'),
#   Synset('scramble.v.03'),
#   Synset('beat.v.10'),
#   Synset('scramble.v.05')],
#  [Synset('inspector.n.01'), Synset('examiner.n.02')],
#  [Synset('straiten.v.01'),
#   Synset('distress.v.02'),
#   Synset('distressed.s.01'),
#   Synset('dysphoric.a.01'),
#   Synset('stressed.s.01'),
#   Synset('disquieted.s.01')],
#  [Synset('smudge.n.01'), Synset('smudge.n.02'), Synset('smear.v.02')],
#  [Synset('accelerator.n.02'),
#   Synset('accelerator.n.01'),
#   Synset('restrict.v.03'),
#   Synset('strangle.v.01'),
#   Synset('choke.v.13')],
#  [Synset('perfection.n.01'),
#   Synset('paragon.n.01'),
#   Synset('perfection.n.03')],
#  [Synset('capable.a.01'),
#   Synset('capable.s.02'),
#   Synset('capable.a.03'),
#   Synset('adequate_to.s.01'),
#   Synset('able.s.02')],
#  [Synset('appliance.n.01')],
#  [Synset('channel.n.01'),
#   Synset('channel.n.02'),
#   Synset('groove.n.01'),
#   Synset('channel.n.04'),
#   Synset('channel.n.05'),
#   Synset('duct.n.01'),
#   Synset('channel.n.07'),
#   Synset('distribution_channel.n.01'),
#   Synset('impart.v.03'),
#   Synset('channel.v.02'),
#   Synset('transmit.v.04')],
#  [Synset('chisel.n.01'),
#   Synset('cheat.v.03'),
#   Synset('cheat.v.01'),
#   Synset('chisel.v.03')],
#  [Synset('chimney.n.01'), Synset('lamp_chimney.n.01')],
#  [Synset('minnow.n.01')],
#  [Synset('sphere.n.01'),
#   Synset('domain.n.02'),
#   Synset('domain.n.03'),
#   Synset('world.n.02'),
#   Synset('knowledge_domain.n.01')],
#  [Synset('shuffle.n.01'),
#   Synset('shamble.n.01'),
#   Synset('shuffle.v.01'),
#   Synset('shuffle.v.02'),
#   Synset('shuffle.v.03')],
#  [Synset('carpenter.n.01'), Synset('carpenter.v.01')],
#  [Synset('pruner.n.01'), Synset('pruner.n.02')],
#  [Synset('package.n.02'),
#   Synset('parcel.n.02'),
#   Synset('tract.n.01'),
#   Synset('package.n.01'),
#   Synset('parcel.v.01'),
#   Synset('parcel.v.02'),
#   Synset('parcel.v.03')],
#  [Synset('squawk.n.01'),
#   Synset('gripe.n.01'),
#   Synset('squawk.v.01'),
#   Synset('gripe.v.01')],
#  [Synset('sheetrock.n.01')],
#  [Synset('trowel.n.01'), Synset('trowel.v.01')],
#  [Synset('nervous.s.01'),
#   Synset('anxious.s.02'),
#   Synset('nervous.a.03'),
#   Synset('aflutter.s.01'),
#   Synset('skittish.s.01')],
#  [Synset('spirit.n.01'),
#   Synset('spirit.n.02'),
#   Synset('spirit.n.03'),
#   Synset('spirit.n.04'),
#   Synset('emotional_state.n.01'),
#   Synset('intent.n.02'),
#   Synset('liveliness.n.02'),
#   Synset('heart.n.06'),
#   Synset('spirit.v.01')],
#  [Synset('equator.n.01'), Synset('equator.n.02')],
#  [Synset('evidence.n.01'),
#   Synset('evidence.n.02'),
#   Synset('evidence.n.03'),
#   Synset('attest.v.01'),
#   Synset('testify.v.02'),
#   Synset('tell.v.07')],
#  [Synset('solar.a.01')],
#  [Synset('research.v.02'),
#   Synset('explore.v.02'),
#   Synset('explore.v.03'),
#   Synset('explore.v.04')],
#  [Synset('distance.n.01'),
#   Synset('distance.n.02'),
#   Synset('distance.n.03'),
#   Synset('distance.n.04'),
#   Synset('distance.n.05'),
#   Synset('distance.n.06'),
#   Synset('distance.v.01'),
#   Synset('outdistance.v.01')],
#  [Synset('mistake.n.01'),
#   Synset('defect.n.03'),
#   Synset('demerit.n.02'),
#   Synset('fault.n.04'),
#   Synset('fault.n.05'),
#   Synset('fault.n.06'),
#   Synset('fault.n.07'),
#   Synset('blame.v.01')],
#  [Synset('settler.n.01')],
#  [Synset('prudence.n.01'), Synset('discretion.n.02')],
#  [Synset('assembly.n.01'),
#   Synset('fabrication.n.04'),
#   Synset('forum.n.02'),
#   Synset('assembly.n.04'),
#   Synset('assembly.n.05'),
#   Synset('assembly.n.06')],
#  [Synset('sheriff.n.01')],
#  [Synset('loiter.v.01'), Synset('tarry.v.02'), Synset('pitchy.s.02')],
#  [Synset('entity.n.01')],
#  [Synset('archives.n.01'), Synset('archive.n.01'), Synset('archive.v.01')],
#  [Synset('disturbance.n.03'), Synset('commotion.n.02'), Synset('whirl.n.01')],
#  [Synset('vacancy.n.01'), Synset('void.n.02')],
#  '##',
#  [Synset('mutate.v.01')],
#  [Synset('platitude.n.01'),
#   Synset('commonplace.s.01'),
#   Synset('commonplace.s.02'),
#   Synset('banal.s.01')],
#  [Synset('gingerbread.n.01')],
#  [Synset('dispute.n.01'),
#   Synset('dispute.n.02'),
#   Synset('challenge.v.01'),
#   Synset('quarrel.v.01')],
#  [Synset('episode.n.01'),
#   Synset('episode.n.02'),
#   Synset('episode.n.03'),
#   Synset('sequence.n.03')],
#  [Synset('sweet.n.03'), Synset('confection.n.02'), Synset('confect.v.02')],
#  [Synset('autograph.n.01'),
#   Synset('autograph.n.02'),
#   Synset('autograph.v.01')],
#  [Synset('petite.n.01'), Synset('bantam.s.01')],
#  [Synset('station.n.01'),
#   Synset('place.n.10'),
#   Synset('station.n.03'),
#   Synset('post.n.01'),
#   Synset('station.n.05'),
#   Synset('station.v.01')],
#  [Synset('lacrosse.n.01')],
#  [Synset('mcintosh.n.01')],
#  [Synset('ignoble.a.01'), Synset('ignoble.s.02')],
#  [Synset('perspiration.n.02')],
#  [Synset('kurta.n.01')],
#  [Synset('hyperion.n.01')],
#  [Synset('withers.n.01'), Synset('shrivel.v.01'), Synset('fade.v.02')],
#  [Synset('geiger.n.01')],
#  '##',
#  [Synset('gannet.n.01')],
#  [Synset('palladium.n.01')],
#  [Synset('brevet.n.01'), Synset('brevet.v.01')],
#  [Synset('booklet.n.01'), Synset('tract.n.03')],
#  [Synset('palindrome.n.01')],
#  '##',
#  [Synset('satsuma.n.01'), Synset('satsuma.n.02')],
#  [Synset('stirrup.n.01'), Synset('stapes.n.01')],
#  '##',
#  [Synset('abundance.n.01'),
#   Synset('abundance.n.02'),
#   Synset('abundance.n.03')],
#  [Synset('black.s.06')],
#  '##',
#  [Synset('announcement.n.01'), Synset('proclamation.n.02')],
#  [Synset('nonsense.n.01')],
#  [Synset('colossal.s.01')],
#  [Synset('columbite-tantalite.n.01')],
#  [Synset('squadron.n.01'), Synset('squadron.n.02'), Synset('squadron.n.03')],
#  [Synset('marinade.v.01')],
#  [Synset('anagrams.n.01'), Synset('anagram.n.01'), Synset('anagram.v.01')],
#  [Synset('veranda.n.01')],
#  [Synset('veranda.n.01')],
#  [Synset('himalayan.a.01')],
#  [Synset('all_right.s.01')],
#  [Synset('aspersion.n.01'),
#   Synset('aspersion.n.02'),
#   Synset('aspersion.n.03')],
#  [Synset('culminate.v.01'),
#   Synset('culminate.v.02'),
#   Synset('culminate.v.03'),
#   Synset('culminate.v.04'),
#   Synset('culminate.v.05')],
#  [Synset('helium.n.01')],
#  '##',
#  [Synset('teflon.n.01')],
#  [Synset('bantam.n.01'), Synset('bantam.s.01')],
#  [Synset('apprentice.n.01'), Synset('apprentice.v.01')],
#  [Synset('loath.s.01'), Synset('reluctant.s.02'), Synset('reluctant.s.03')],
#  [Synset('heritage.n.01'),
#   Synset('inheritance.n.04'),
#   Synset('inheritance.n.02'),
#   Synset('inheritance.n.01')],
#  [Synset('sojourner.n.01')],
#  [Synset('derogative.s.01')],
#  [Synset('paralysis.n.01'), Synset('palsy.n.02'), Synset('palsy.v.01')],
#  [Synset('lascaux.n.01')],
#  [Synset('synesthesia.n.01')],
#  [Synset('synesthesia.n.01')],
#  [Synset('nefarious.s.01')],
#  [Synset('halogen.n.01')],
#  [Synset('gallium.n.01')],
#  [Synset('smelter.n.01')],
#  [Synset('hymnal.n.01')],
#  [Synset('tartaric.a.01')],
#  '##',
#  [Synset('haitian.n.01'), Synset('haitian.a.01')],
#  [Synset('divan.n.01'),
#   Synset('divan.n.02'),
#   Synset('divan.n.03'),
#   Synset('divan.n.04')],
#  [Synset('badminton.n.01')],
#  [Synset('bayonet.n.01'), Synset('bayonet.v.01')],
#  [Synset('currycomb.n.01'), Synset('currycomb.v.01')],
#  [Synset('disdainful.s.02')],
#  [Synset('hesitate.v.01'), Synset('hesitate.v.02')],
#  [Synset('opportunity.n.01')],
#  [Synset('apollo.n.01')],
#  [Synset('accord.n.02'), Synset('accordance.n.02')],
#  [Synset('atmospheric.a.01')],
#  [Synset('levee.n.01'), Synset('levee.n.02'), Synset('levee.n.03')],
#  [Synset('precariously.r.01')],
#  [Synset('proportionate.a.01'),
#   Synset('proportionate.s.02'),
#   Synset('harmonious.s.02')],
#  [Synset('suffuse.v.01'), Synset('suffuse.v.02')],
#  [Synset('accelerate.v.01'), Synset('accelerate.v.02')],
#  [Synset('coincidence.n.01'),
#   Synset('coincidence.n.02'),
#   Synset('concurrence.n.04')],
#  [Synset('esteemed.s.01'), Synset('prestigious.s.02')],
#  [Synset('emphatic.s.01'), Synset('emphatic.s.02'), Synset('emphatic.s.03')],
#  [Synset('pollute.v.01'),
#   Synset('contaminate.v.02'),
#   Synset('contaminated.a.01'),
#   Synset('contaminated.s.02')],
#  [Synset('madagascar.n.01'), Synset('madagascar.n.02')],
#  [Synset('exposure.n.01'),
#   Synset('exposure.n.02'),
#   Synset('exposure.n.03'),
#   Synset('exposure.n.04'),
#   Synset('vulnerability.n.01'),
#   Synset('exposure.n.06'),
#   Synset('photograph.n.01'),
#   Synset('exposure.n.08'),
#   Synset('exposure.n.09'),
#   Synset('exposure.n.10')],
#  [Synset('chute.v.01')],
#  [Synset('sporadically.r.01')],
#  [Synset('intrigue.v.01'),
#   Synset('scheme.v.01'),
#   Synset('challenging.s.03'),
#   Synset('intriguing.s.02')],
#  [Synset('absorbent.a.01')],
#  [Synset('inexplicable.a.01'), Synset('incomprehensible.a.02')],
#  [Synset('merrimack.n.01')],
#  [Synset('sinai.n.01'), Synset('sinai.n.02'), Synset('sinai.n.03')],
#  [Synset('misdemeanor.n.01')],
#  [Synset('misdemeanor.n.01')],
#  [Synset('asparagus.n.01'), Synset('asparagus.n.02')],
#  [Synset('consolation.n.01'),
#   Synset('solace.n.02'),
#   Synset('consolation.n.02'),
#   Synset('comfort.v.01')],
#  '##',
#  [Synset('guanine.n.01')],
#  '##',
#  [Synset('remedy.n.02'), Synset('curative.s.01'), Synset('therapeutic.a.02')],
#  [Synset('disruptive.s.01')],
#  [Synset('commodore.n.01')],
#  [Synset('dramatist.n.01')],
#  [Synset('doddering.s.01')],
#  [Synset('laryngitis.n.01')],
#  [Synset('proximo.s.01')],
#  [Synset('guerrilla.n.01')],
#  [Synset('guerrilla.n.01')],
#  [Synset('giza.n.01')],
#  [Synset('fastness.n.02'), Synset('immutability.n.01')],
#  [Synset('jodhpurs.n.01'), Synset('jodhpur.n.01')],
#  [Synset('mercury.n.01')],
#  '##',
#  [Synset('denunciation.n.01')],
#  [Synset('columbia.n.01'),
#   Synset('columbia.n.02'),
#   Synset('columbia.n.03'),
#   Synset('columbia.n.04'),
#   Synset('columbia_university.n.01')]]

# %%
def dict_convert(dict_set):
    dict_type={'v': 'verb','a':'adjective', 'n':'noun','r':'adverb','s': 'noun'}
    x=[]
    for each in dict_set:
        if each != '##':
            x.append(dict_type[each[0].pos()])
        else:
            x.append('s')
    return np.array(x)
x=dict_convert(dictset)

# %%
x
# Out:
# array(['noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun',
#        's', 'noun', 's', 'noun', 'noun', 'noun', 'noun', 'noun', 'verb',
#        'noun', 'noun', 'noun', 'noun', 'noun', 'verb', 'verb', 'verb',
#        's', 'noun', 'noun', 'adjective', 'noun', 'verb', 'noun', 'noun',
#        'noun', 'noun', 'noun', 'verb', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'verb', 'noun', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'adverb', 'noun', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'verb', 'noun', 'noun', 'adjective', 'noun', 'noun',
#        'noun', 'noun', 'adjective', 'noun', 'verb', 'noun', 'noun',
#        'noun', 'verb', 'noun', 'noun', 'verb', 'verb', 'noun', 'noun',
#        'verb', 'noun', 'noun', 'verb', 'noun', 'noun', 'noun', 'noun',
#        'verb', 'noun', 'noun', 'noun', 'adjective', 'noun', 'noun',
#        'noun', 'noun', 'verb', 'noun', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'verb', 'noun', 'verb', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 's',
#        'noun', 'adjective', 'noun', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'verb', 'noun',
#        'noun', 'noun', 'verb', 'noun', 'noun', 'verb', 'noun', 'noun',
#        'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun',
#        'adverb', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'verb', 'noun', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'noun', 'adjective', 'noun', 'noun', 'noun',
#        'verb', 'noun', 'noun', 'verb', 'noun', 'noun', 'verb', 'noun',
#        'noun', 'noun', 'adjective', 'noun', 'noun', 'noun', 'noun',
#        'adjective', 'noun', 'adverb', 'verb', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'verb', 'noun', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'noun', 'noun', 'noun', 's', 'noun', 'noun',
#        'verb', 'noun', 'noun', 'noun', 'noun', 'noun', 'adjective',
#        'noun', 'noun', 'noun', 'verb', 'noun', 'noun', 'noun', 'verb',
#        'noun', 'verb', 'noun', 'noun', 'noun', 'noun', 'adjective',
#        'noun', 'noun', 'adjective', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'noun', 'noun', 'verb', 'noun', 'noun', 'noun',
#        'adjective', 'verb', 'noun', 'verb', 'verb', 'noun', 'noun',
#        'noun', 'noun', 'noun', 'noun', 'verb', 'verb', 'adverb', 'noun',
#        'noun', 'noun', 'adjective', 'noun', 'noun', 'noun', 'noun',
#        'verb', 'noun', 'adjective', 'noun', 'noun', 'noun', 'verb',
#        'adjective', 'noun', 'noun', 'verb', 'noun', 'verb', 'noun',
#        'noun', 'noun', 'adjective', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'noun', 'noun', 'noun', 'adjective', 'verb',
#        'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'verb', 'noun',
#        'noun', 'noun', 'noun', 's', 'verb', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun',
#        'adjective', 'noun', 'noun', 'noun', 'noun', 'noun', 's', 'noun',
#        'noun', 'noun', 'noun', 'noun', 's', 'noun', 'noun', 's', 'noun',
#        'noun', 's', 'noun', 'noun', 'noun', 'noun', 'noun', 'verb',
#        'noun', 'noun', 'noun', 'adjective', 'noun', 'noun', 'verb',
#        'noun', 's', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'adjective', 's', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'verb', 'noun', 'noun', 'noun', 'adjective',
#        'noun', 'adverb', 'adjective', 'verb', 'verb', 'noun', 'noun',
#        'noun', 'verb', 'noun', 'noun', 'verb', 'adverb', 'verb',
#        'adjective', 'adjective', 'noun', 'noun', 'noun', 'noun', 'noun',
#        'noun', 's', 'noun', 's', 'noun', 'noun', 'noun', 'noun', 'noun',
#        'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun',
#        's', 'noun', 'noun'], dtype='<U9')
